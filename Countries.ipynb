# %% [markdown]
# <a href="https://colab.research.google.com/github/khalidmahmudsourov-code/Python_Basic/blob/main/Countries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-14451f50-ab1a-46bb-84db-e2271b9c30fd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-14451f50-ab1a-46bb-84db-e2271b9c30fd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("Countries.csv")
df
# Out:
#                 country                             country_long  \
# 0           Afghanistan             Islamic State of Afghanistan
# 1               Albania                      Republic of Albania
# 2               Algeria  People's Democratic Republic of Algeria
# 3               Andorra                  Principality of Andorra
# 4                Angola              People's Republic of Angola
# ..                  ...                                      ...
# 189             Vietnam            Socialist Republic of Vietnam
# 190  West Bank and Gaza                       West Bank and Gaza
# 191               Yemen                        Republic of Yemen
# 192              Zambia                       Republic of Zambia
# 193            Zimbabwe                     Republic of Zimbabwe
#
#                currency      capital_city              region continent  \
# 0        Afghan afghani             Kabul       Southern Asia      Asia
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Data columns (total 64 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   country                                  194 non-null    object
#  1   country_long                             194 non-null    object
#  2   currency                                 194 non-null    object
#  3   capital_city                             194 non-null    object
#  4   region                                   194 non-null    object
#  5   continent                                194 non-null    object
#  6   demonym                                  194 non-null    object
#  7   latitude                                 194 non-null    float64
#  8   longitude                                194 non-null    float64
#  9   agricultural_land                        193 non-null    float64
# ...

# %%
df[df['population']==df['population'].max()]['country']
# Out:
# 75    India
# Name: country, dtype: object

# %%
df[df['population']==df['population'].max()]['capital_city']
# Out:
# 75    New Delhi
# Name: capital_city, dtype: object

# %%
df[df['population']==df['population'].min()]['country']
# Out:
# 179    Tuvalu
# Name: country, dtype: object

# %%
df[df['population']==df['population'].min()]['capital_city']
# Out:
# 179    Funafuti
# Name: capital_city, dtype: object

# %%
df_demo_score = df.sort_values(by='democracy_score',ascending=False)
df_demo_score['country'].head()
# Out:
# 127         Norway
# 74         Iceland
# 164         Sweden
# 122    New Zealand
# 46         Denmark
# Name: country, dtype: object

# %%
df['region'].value_counts().count()
# Out:
# np.int64(22)

# %%
df['country'][df['region']=='Eastern Europe'].count()
# Out:
# np.int64(10)

# %%
df_population = df.sort_values(by='population',ascending=False)
df_population['country'].head()
# Out:
# 75             India
# 34             China
# 184    United States
# 76         Indonesia
# 129         Pakistan
# Name: country, dtype: object

# %%
df['political_leader'][df['population']==df['population'].nlargest(2).iloc[1]]
# Out:
# 34    Xi Jinping
# Name: political_leader, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Data columns (total 64 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   country                                  194 non-null    object
#  1   country_long                             194 non-null    object
#  2   currency                                 194 non-null    object
#  3   capital_city                             194 non-null    object
#  4   region                                   194 non-null    object
#  5   continent                                194 non-null    object
#  6   demonym                                  194 non-null    object
#  7   latitude                                 194 non-null    float64
#  8   longitude                                194 non-null    float64
#  9   agricultural_land                        193 non-null    float64
# ...

# %%
df[df['political_leader'].isnull()]['country'].count()
# Out:
# np.int64(7)

# %%
count = 0
def republic_count(txt):
  global count
  if 'Republic' in txt:
    count += 1
    return count

# %%
df['country_long'].apply(republic_count)
print(count)
# Out:
# 125

# %%
df_africa = df[df['continent']=='Africa']
df_africa[df_africa['population']==df_africa['population'].max()]['country']

# %%
df_africa[df_africa['population'] == df_africa['population'].max()]['country']
# Out:
# 125    Nigeria
# Name: country, dtype: object
